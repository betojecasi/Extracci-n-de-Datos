# %% [markdown]
# <a href="https://colab.research.google.com/github/betojecasi/Extracci-n-de-Datos/blob/main/1_Extracci%C3%B3n_de_Datos_Tarea.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerias requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Cargar achivo csv desde equipo
from google.colab import files
files.upload()

# %%
#Convertir en Dataframe
df=pd.read_csv("CountryTable.csv")
#df

# %%
#Imprimimos las primeras filas o registros del Dataframe
df.head(5)

# %% [markdown]
# **Filtros basicos para variables cualitativas**

# %%
#Filtro por objeto
filtro1=df[df["region"]=="Caribbean"]
filtro1
#Se elige este filtro para estudiar más a fondo los paises ubicados en el caribe

# %%
filtro1.to_csv("Filtro1.csv")

# %%
from google.colab import files

files.download("Filtro1.csv")

# %%
#Filtro por filas
#filtro2=df.iloc[300:302,:]
filtro2=df.iloc[[10,20,30],:] #filas no consecutivas
filtro2
#Se eligen estas filas para comparar diferentes areas y paises

# %%
filtro2.to_csv("Filtro2.csv")

# %%
from google.colab import files

files.download("Filtro2.csv")

# %%
#Filtro por columnas
#filtro3=df.iloc[ : , [1,4,6]] #columnas no consecutivas
filtro3=df.iloc[ : , 0:5] #columnas consecutivas
filtro3
#Se elige este filtro para solo estudiar las primeras 5 columnas (code, name, continent, region, sufrace_area)

# %%
filtro3.to_csv("Filtro3.csv")

# %%
from google.colab import files

files.download("Filtro3.csv")

# %%
df=pd.read_csv("CountryTable.csv", index_col=3)
df
# Out:
#                           code          name      continent  surface_area  \
# region
# Caribbean                  ABW         Aruba  North America         193.0
# Southern and Central Asia  AFG   Afghanistan           Asia      652090.0
# Central Africa             AGO        Angola         Africa     1246700.0
# Caribbean                  AIA      Anguilla  North America          96.0
# Southern Europe            ALB       Albania         Europe       28748.0
# ...                        ...           ...            ...           ...
# Middle East                YEM         Yemen           Asia      527968.0
# Southern Europe            YuG    Yugoslavia         Europe      102173.0
# Southern Africa            ZAF  South Africa         Africa     1221037.0
# Eastern Africa             ZMB        Zambia         Africa      752618.0
# Eastern Africa             ZWE      Zimbabwe         Africa      390757.0
#
# ...

# %%
#Paso 2: Aplicamos filtro de filas vs columnas
filtro4=df.loc[['Middle East','Southern Europe'],['life_expectancy']]
filtro4
#Aqui aplicamos un filtro para ver solo la esperanza de vida en el medio oriente y el sur de europa
# Out:
#                  life_expectancy
# region
# Middle East                 74.1
# Middle East                 66.4
# Middle East                 62.9
# Middle East                 73.0
# Middle East                 76.7
# Middle East                 64.5
# Middle East                 66.5
# Middle East                 78.6
# Middle East                 77.4
# Middle East                 76.1
# Middle East                 71.3
# Middle East                 71.8
# Middle East                 71.4
# Middle East                 72.4
# Middle East                 67.8
# Middle East                 68.5
# Middle East                 71.0
# Middle East                 59.8
# Southern Europe             71.6
# Southern Europe             83.5
# Southern Europe             71.5
# Southern Europe             78.8
# Southern Europe             79.0
# Southern Europe             78.4
# Southern Europe             73.7
# Southern Europe             79.0
# Southern Europe             73.8
# ...

# %%
filtro4.to_csv("Filtro4.csv")

# %%
from google.colab import files

files.download("Filtro4.csv")

# %%
#Filtro por cabecera
filtro5=df.head(8)
filtro5
#Filtramos solo las primeros 8 datos de la base de datos
# Out:
#                           code                  name      continent  \
# region
# Caribbean                  ABW                 Aruba  North America
# Southern and Central Asia  AFG           Afghanistan           Asia
# Central Africa             AGO                Angola         Africa
# Caribbean                  AIA              Anguilla  North America
# Southern Europe            ALB               Albania         Europe
# Southern Europe            AND               Andorra         Europe
# Caribbean                  ANT  Netherlands Antilles  North America
# Middle East                ARE  united Arab Emirates           Asia
#
#                            surface_area  independence_year  population  \
# region
# Caribbean                         193.0                NaN      103000
# Southern and Central Asia      652090.0             1919.0    22720000
# Central Africa                1246700.0             1975.0    12878000
# ...

# %%
filtro5.to_csv("Filtro5.csv")

# %%
from google.colab import files

files.download("Filtro5.csv")

# %% [markdown]
# **Filtros basicos para variables cuantitativas**

# %%
#Filtro por comparacion
filtro6=df[df["independence_year"]> 1900]
filtro6
#Aqui filtramos los que de independizaron despues de 1900, para saber que tan recientemente se independizaron
#ciertos paises

# %%
filtro6.to_csv("Filtro6.csv")

# %%
from google.colab import files

files.download("Filtro6.csv")

# %%
#Filtro Y
filtro7=df[(df['independence_year']>1900) & (df['continent']=='Europe')]
filtro7
#Aqui hacemos lo mismo solo que especificamente de los paises de Europa y los paises con independecia despues de 1900

# %%
filtro7.to_csv("Filtro7.csv")

# %%
from google.colab import files

files.download("Filtro7.csv")

# %%
#Filtro o
filtro8=df[(df["independence_year"]>1900) | (df["continent"]=="Africa")]
filtro8
#Aqui se incluyen los paises con independencia despues de 1900 o los del continente Africa

# %%
filtro8.to_csv("Filtro8.csv")

# %%
from google.colab import files

files.download("Filtro8.csv")

# %%
#Filtro not
filtro9=df[~(df["independence_year"]>1900) & ~ (df["continent"]=="North America")]
filtro9
#Aqui no filtra los datos que se ingresan sino que los evade (nu muestra a norte america ni a los paises con independecia >1900)

# %%
filtro9.to_csv("Filtro9.csv")

# %%
from google.colab import files

files.download("Filtro9.csv")
